# %%
import gym

# %%
from stable_baselines.common.policies import MlpPolicy
from stable_baselines.common.vec_env import DummyVecEnv
from stable_baselines import PPO2

env = gym.make('CartPole-v1')
# Optional: PPO2 requires a vectorized environment to run
# the env is now wrapped automatically when passing it to the constructor
# env = DummyVecEnv([lambda: env])

model = PPO2(MlpPolicy, env, verbose=1)
model.learn(total_timesteps=10000)

obs = env.reset()
for i in range(1000):
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    env.render()
    if i == 999:
        env.close()
# Out:
# Wrapping the env in a DummyVecEnv.
# WARNING:tensorflow:From /Users/sellintang/miniconda/envs/tf/lib/python3.6/site-packages/stable_baselines/common/policies.py:561: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From /Users/sellintang/miniconda/envs/tf/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /Users/sellintang/miniconda/envs/tf/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /Users/sellintang/miniconda/envs/tf/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# ---------------------------------------
# | approxkl           | 7.5628595e-06  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.00539        |
# | fps                | 23             |
# | n_updates          | 1              |
# | policy_entropy     | 0.69313943     |
# | policy_loss        | -0.00012638699 |
# | serial_timesteps   | 128            |
# | time_elapsed       | 1.29e-05       |
# | total_timesteps    | 128            |
# | value_loss         | 26.995514      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 5.1076e-06    |
# | clipfrac           | 0.0           |
# | explained_variance | -0.000651     |
# | fps                | 288           |
# | n_updates          | 2             |
# | policy_entropy     | 0.6931387     |
# | policy_loss        | -0.0002699438 |
# | serial_timesteps   | 256           |
# | time_elapsed       | 5.5           |
# | total_timesteps    | 256           |
# | value_loss         | 42.198772     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00010519456 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0104       |
# | fps                | 493           |
# | n_updates          | 3             |
# | policy_entropy     | 0.6930059     |
# | policy_loss        | -0.002871252  |
# | serial_timesteps   | 384           |
# | time_elapsed       | 5.95          |
# | total_timesteps    | 384           |
# | value_loss         | 40.48384      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0001080371  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0103        |
# | fps                | 244           |
# | n_updates          | 4             |
# | policy_entropy     | 0.69234085    |
# | policy_loss        | -0.0021538313 |
# | serial_timesteps   | 512           |
# | time_elapsed       | 6.21          |
# | total_timesteps    | 512           |
# | value_loss         | 44.86636      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0002594821  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00799       |
# | fps                | 225           |
# | n_updates          | 5             |
# | policy_entropy     | 0.6900275     |
# | policy_loss        | -0.0044346987 |
# | serial_timesteps   | 640           |
# | time_elapsed       | 6.74          |
# | total_timesteps    | 640           |
# | value_loss         | 27.535002     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00025475965 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0157        |
# | fps                | 464           |
# | n_updates          | 6             |
# | policy_entropy     | 0.6870904     |
# | policy_loss        | -0.002572122  |
# | serial_timesteps   | 768           |
# | time_elapsed       | 7.31          |
# | total_timesteps    | 768           |
# | value_loss         | 34.722183     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0005025885 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.0155       |
# | fps                | 423          |
# | n_updates          | 7            |
# | policy_entropy     | 0.68012744   |
# | policy_loss        | -0.008516116 |
# | serial_timesteps   | 896          |
# | time_elapsed       | 7.58         |
# | total_timesteps    | 896          |
# | value_loss         | 32.904484    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00030841702 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0183        |
# | fps                | 393           |
# | n_updates          | 8             |
# | policy_entropy     | 0.6781311     |
# | policy_loss        | -0.0039049552 |
# | serial_timesteps   | 1024          |
# | time_elapsed       | 7.89          |
# | total_timesteps    | 1024          |
# | value_loss         | 47.342834     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00024856767 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.000105      |
# | fps                | 435           |
# | n_updates          | 9             |
# | policy_entropy     | 0.6719786     |
# | policy_loss        | -0.003786781  |
# | serial_timesteps   | 1152          |
# | time_elapsed       | 8.21          |
# | total_timesteps    | 1152          |
# | value_loss         | 54.94792      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00022223168 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00276      |
# | fps                | 410           |
# | n_updates          | 10            |
# | policy_entropy     | 0.66635257    |
# | policy_loss        | -0.003232996  |
# | serial_timesteps   | 1280          |
# | time_elapsed       | 8.51          |
# | total_timesteps    | 1280          |
# | value_loss         | 39.694622     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0004202931 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.012        |
# | fps                | 389          |
# | n_updates          | 11           |
# | policy_entropy     | 0.6491303    |
# | policy_loss        | 0.002954073  |
# | serial_timesteps   | 1408         |
# | time_elapsed       | 8.82         |
# | total_timesteps    | 1408         |
# | value_loss         | 39.37238     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00018289503 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00357       |
# | fps                | 432           |
# | n_updates          | 12            |
# | policy_entropy     | 0.66730726    |
# | policy_loss        | 0.0045342334  |
# | serial_timesteps   | 1536          |
# | time_elapsed       | 9.15          |
# | total_timesteps    | 1536          |
# | value_loss         | 44.84114      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0003594275 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.0151       |
# | fps                | 429          |
# | n_updates          | 13           |
# | policy_entropy     | 0.6558958    |
# | policy_loss        | -0.005805105 |
# | serial_timesteps   | 1664         |
# | time_elapsed       | 9.45         |
# | total_timesteps    | 1664         |
# | value_loss         | 34.76347     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00068477873 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.024         |
# | fps                | 284           |
# | n_updates          | 14            |
# | policy_entropy     | 0.64121425    |
# | policy_loss        | -0.0015111859 |
# | serial_timesteps   | 1792          |
# | time_elapsed       | 9.75          |
# | total_timesteps    | 1792          |
# | value_loss         | 30.52889      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00024599544 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00171      |
# | fps                | 244           |
# | n_updates          | 15            |
# | policy_entropy     | 0.62541574    |
# | policy_loss        | -0.0038237385 |
# | serial_timesteps   | 1920          |
# | time_elapsed       | 10.2          |
# | total_timesteps    | 1920          |
# | value_loss         | 65.90703      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00035386148 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0333        |
# | fps                | 345           |
# | n_updates          | 16            |
# | policy_entropy     | 0.6086082     |
# | policy_loss        | -0.002043874  |
# | serial_timesteps   | 2048          |
# | time_elapsed       | 10.7          |
# | total_timesteps    | 2048          |
# | value_loss         | 27.22083      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00016329049  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0143         |
# | fps                | 312            |
# | n_updates          | 17             |
# | policy_entropy     | 0.6192836      |
# | policy_loss        | -0.00095928065 |
# | serial_timesteps   | 2176           |
# | time_elapsed       | 11.1           |
# | total_timesteps    | 2176           |
# | value_loss         | 59.16698       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00018551966 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0212        |
# | fps                | 318           |
# | n_updates          | 18            |
# | policy_entropy     | 0.623703      |
# | policy_loss        | -0.004529696  |
# | serial_timesteps   | 2304          |
# | time_elapsed       | 11.5          |
# | total_timesteps    | 2304          |
# | value_loss         | 54.220814     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00054236356 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0163        |
# | fps                | 479           |
# | n_updates          | 19            |
# | policy_entropy     | 0.59401524    |
# | policy_loss        | 8.5441745e-05 |
# | serial_timesteps   | 2432          |
# | time_elapsed       | 11.9          |
# | total_timesteps    | 2432          |
# | value_loss         | 44.644142     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 5.220268e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0127        |
# | fps                | 555           |
# | n_updates          | 20            |
# | policy_entropy     | 0.60956156    |
# | policy_loss        | -0.0012541903 |
# | serial_timesteps   | 2560          |
# | time_elapsed       | 12.2          |
# | total_timesteps    | 2560          |
# | value_loss         | 58.95251      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0002034509  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0166        |
# | fps                | 508           |
# | n_updates          | 21            |
# | policy_entropy     | 0.6024573     |
# | policy_loss        | -0.0016692007 |
# | serial_timesteps   | 2688          |
# | time_elapsed       | 12.4          |
# | total_timesteps    | 2688          |
# | value_loss         | 59.023735     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.7730552e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0243        |
# | fps                | 513           |
# | n_updates          | 22            |
# | policy_entropy     | 0.5900344     |
# | policy_loss        | 1.6073347e-05 |
# | serial_timesteps   | 2816          |
# | time_elapsed       | 12.7          |
# | total_timesteps    | 2816          |
# | value_loss         | 40.836422     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00014602185 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0333        |
# | fps                | 510           |
# | n_updates          | 23            |
# | policy_entropy     | 0.5869276     |
# | policy_loss        | -0.0007231714 |
# | serial_timesteps   | 2944          |
# | time_elapsed       | 12.9          |
# | total_timesteps    | 2944          |
# | value_loss         | 74.84479      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 4.677187e-05 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.0232       |
# | fps                | 514          |
# | n_updates          | 24           |
# | policy_entropy     | 0.58616394   |
# | policy_loss        | 0.0007618888 |
# | serial_timesteps   | 3072         |
# | time_elapsed       | 13.2         |
# | total_timesteps    | 3072         |
# | value_loss         | 52.620064    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 2.57524e-05  |
# | clipfrac           | 0.0          |
# | explained_variance | 0.0148       |
# | fps                | 481          |
# | n_updates          | 25           |
# | policy_entropy     | 0.6015123    |
# | policy_loss        | 8.091057e-05 |
# | serial_timesteps   | 3200         |
# | time_elapsed       | 13.4         |
# | total_timesteps    | 3200         |
# | value_loss         | 52.815166    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 4.9088514e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0213        |
# | fps                | 545           |
# | n_updates          | 26            |
# | policy_entropy     | 0.6199522     |
# | policy_loss        | -0.0017871669 |
# | serial_timesteps   | 3328          |
# | time_elapsed       | 13.7          |
# | total_timesteps    | 3328          |
# | value_loss         | 45.579556     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 3.7361842e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0298         |
# | fps                | 461            |
# | n_updates          | 27             |
# | policy_entropy     | 0.6027355      |
# | policy_loss        | -0.00094441907 |
# | serial_timesteps   | 3456           |
# | time_elapsed       | 13.9           |
# | total_timesteps    | 3456           |
# | value_loss         | 88.02916       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 7.611827e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0176       |
# | fps                | 512           |
# | n_updates          | 28            |
# | policy_entropy     | 0.5829184     |
# | policy_loss        | 0.00063798006 |
# | serial_timesteps   | 3584          |
# | time_elapsed       | 14.2          |
# | total_timesteps    | 3584          |
# | value_loss         | 72.2165       |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.8777191e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0704        |
# | fps                | 499           |
# | n_updates          | 29            |
# | policy_entropy     | 0.6225813     |
# | policy_loss        | -9.555835e-05 |
# | serial_timesteps   | 3712          |
# | time_elapsed       | 14.5          |
# | total_timesteps    | 3712          |
# | value_loss         | 58.017696     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 2.368126e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0306         |
# | fps                | 545            |
# | n_updates          | 30             |
# | policy_entropy     | 0.575188       |
# | policy_loss        | -0.00066551485 |
# | serial_timesteps   | 3840           |
# | time_elapsed       | 14.7           |
# | total_timesteps    | 3840           |
# | value_loss         | 76.82952       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00019933499 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0564        |
# | fps                | 531           |
# | n_updates          | 31            |
# | policy_entropy     | 0.58308274    |
# | policy_loss        | -0.0029168685 |
# | serial_timesteps   | 3968          |
# | time_elapsed       | 14.9          |
# | total_timesteps    | 3968          |
# | value_loss         | 56.30654      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00015434604 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0174        |
# | fps                | 545           |
# | n_updates          | 32            |
# | policy_entropy     | 0.59870493    |
# | policy_loss        | 0.0007940617  |
# | serial_timesteps   | 4096          |
# | time_elapsed       | 15.2          |
# | total_timesteps    | 4096          |
# | value_loss         | 54.800392     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.9811235e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0904        |
# | fps                | 536           |
# | n_updates          | 33            |
# | policy_entropy     | 0.5921226     |
# | policy_loss        | 0.00047437067 |
# | serial_timesteps   | 4224          |
# | time_elapsed       | 15.4          |
# | total_timesteps    | 4224          |
# | value_loss         | 67.55212      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00022304413  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.084          |
# | fps                | 543            |
# | n_updates          | 34             |
# | policy_entropy     | 0.57217747     |
# | policy_loss        | -0.00026122696 |
# | serial_timesteps   | 4352           |
# | time_elapsed       | 15.7           |
# | total_timesteps    | 4352           |
# | value_loss         | 55.385544      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 1.448279e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.168         |
# | fps                | 549           |
# | n_updates          | 35            |
# | policy_entropy     | 0.590198      |
# | policy_loss        | 0.00031291624 |
# | serial_timesteps   | 4480          |
# | time_elapsed       | 15.9          |
# | total_timesteps    | 4480          |
# | value_loss         | 91.715294     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00018398953 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.121         |
# | fps                | 538           |
# | n_updates          | 36            |
# | policy_entropy     | 0.5929695     |
# | policy_loss        | 0.00036028516 |
# | serial_timesteps   | 4608          |
# | time_elapsed       | 16.1          |
# | total_timesteps    | 4608          |
# | value_loss         | 50.9225       |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 2.9834182e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0132         |
# | fps                | 467            |
# | n_updates          | 37             |
# | policy_entropy     | 0.5745232      |
# | policy_loss        | -0.00043874118 |
# | serial_timesteps   | 4736           |
# | time_elapsed       | 16.4           |
# | total_timesteps    | 4736           |
# | value_loss         | 47.648727      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 1.1575272e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0509        |
# | fps                | 419           |
# | n_updates          | 38            |
# | policy_entropy     | 0.5772947     |
# | policy_loss        | 4.007283e-05  |
# | serial_timesteps   | 4864          |
# | time_elapsed       | 16.6          |
# | total_timesteps    | 4864          |
# | value_loss         | 44.94853      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00015567678 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0982        |
# | fps                | 566           |
# | n_updates          | 39            |
# | policy_entropy     | 0.5817503     |
# | policy_loss        | 8.848496e-06  |
# | serial_timesteps   | 4992          |
# | time_elapsed       | 17            |
# | total_timesteps    | 4992          |
# | value_loss         | 53.21643      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 5.8296e-05    |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0463        |
# | fps                | 538           |
# | n_updates          | 40            |
# | policy_entropy     | 0.5573783     |
# | policy_loss        | -0.0004178167 |
# | serial_timesteps   | 5120          |
# | time_elapsed       | 17.2          |
# | total_timesteps    | 5120          |
# | value_loss         | 64.16085      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 3.6291232e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.141          |
# | fps                | 571            |
# | n_updates          | 41             |
# | policy_entropy     | 0.6019845      |
# | policy_loss        | -7.7765435e-07 |
# | serial_timesteps   | 5248           |
# | time_elapsed       | 17.4           |
# | total_timesteps    | 5248           |
# | value_loss         | 66.08175       |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 2.763006e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.285          |
# | fps                | 563            |
# | n_updates          | 42             |
# | policy_entropy     | 0.6111962      |
# | policy_loss        | -0.00025456445 |
# | serial_timesteps   | 5376           |
# | time_elapsed       | 17.6           |
# | total_timesteps    | 5376           |
# | value_loss         | 61.781364      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00020919234 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0205        |
# | fps                | 592           |
# | n_updates          | 43            |
# | policy_entropy     | 0.58251035    |
# | policy_loss        | 0.003287328   |
# | serial_timesteps   | 5504          |
# | time_elapsed       | 17.9          |
# | total_timesteps    | 5504          |
# | value_loss         | 61.699203     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 4.7213347e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0203       |
# | fps                | 538           |
# | n_updates          | 44            |
# | policy_entropy     | 0.58317345    |
# | policy_loss        | -0.0012216023 |
# | serial_timesteps   | 5632          |
# | time_elapsed       | 18.1          |
# | total_timesteps    | 5632          |
# | value_loss         | 62.27523      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.0725532e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.051        |
# | fps                | 569           |
# | n_updates          | 45            |
# | policy_entropy     | 0.57613826    |
# | policy_loss        | -0.0011691777 |
# | serial_timesteps   | 5760          |
# | time_elapsed       | 18.3          |
# | total_timesteps    | 5760          |
# | value_loss         | 87.451164     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0005182389  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.108         |
# | fps                | 556           |
# | n_updates          | 46            |
# | policy_entropy     | 0.60274637    |
# | policy_loss        | -0.0005813427 |
# | serial_timesteps   | 5888          |
# | time_elapsed       | 18.6          |
# | total_timesteps    | 5888          |
# | value_loss         | 78.67763      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 5.160323e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.358         |
# | fps                | 571           |
# | n_updates          | 47            |
# | policy_entropy     | 0.628876      |
# | policy_loss        | 0.00049038045 |
# | serial_timesteps   | 6016          |
# | time_elapsed       | 18.8          |
# | total_timesteps    | 6016          |
# | value_loss         | 63.89165      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0003039916  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.124         |
# | fps                | 528           |
# | n_updates          | 48            |
# | policy_entropy     | 0.5869733     |
# | policy_loss        | -0.0041578757 |
# | serial_timesteps   | 6144          |
# | time_elapsed       | 19            |
# | total_timesteps    | 6144          |
# | value_loss         | 47.667732     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 8.25602e-05   |
# | clipfrac           | 0.0           |
# | explained_variance | -0.000454     |
# | fps                | 584           |
# | n_updates          | 49            |
# | policy_entropy     | 0.575993      |
# | policy_loss        | -0.0031992903 |
# | serial_timesteps   | 6272          |
# | time_elapsed       | 19.3          |
# | total_timesteps    | 6272          |
# | value_loss         | 84.350784     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.001367972   |
# | clipfrac           | 0.001953125   |
# | explained_variance | 0.156         |
# | fps                | 538           |
# | n_updates          | 50            |
# | policy_entropy     | 0.5871013     |
# | policy_loss        | -0.0075590666 |
# | serial_timesteps   | 6400          |
# | time_elapsed       | 19.5          |
# | total_timesteps    | 6400          |
# | value_loss         | 76.483925     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 6.0358972e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.166         |
# | fps                | 529           |
# | n_updates          | 51            |
# | policy_entropy     | 0.57781315    |
# | policy_loss        | -8.543581e-05 |
# | serial_timesteps   | 6528          |
# | time_elapsed       | 19.7          |
# | total_timesteps    | 6528          |
# | value_loss         | 53.54015      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.1788497e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.362         |
# | fps                | 562           |
# | n_updates          | 52            |
# | policy_entropy     | 0.5778264     |
# | policy_loss        | 7.1899267e-06 |
# | serial_timesteps   | 6656          |
# | time_elapsed       | 20            |
# | total_timesteps    | 6656          |
# | value_loss         | 78.99753      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0018123157 |
# | clipfrac           | 0.03515625   |
# | explained_variance | 0.161        |
# | fps                | 558          |
# | n_updates          | 53           |
# | policy_entropy     | 0.5579068    |
# | policy_loss        | 0.0060902215 |
# | serial_timesteps   | 6784         |
# | time_elapsed       | 20.2         |
# | total_timesteps    | 6784         |
# | value_loss         | 31.7527      |
# -------------------------------------
# ---------------------------------------
# | approxkl           | 1.999007e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.451          |
# | fps                | 602            |
# | n_updates          | 54             |
# | policy_entropy     | 0.60745186     |
# | policy_loss        | -3.3960445e-05 |
# | serial_timesteps   | 6912           |
# | time_elapsed       | 20.4           |
# | total_timesteps    | 6912           |
# | value_loss         | 77.52597       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00035227096 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.307         |
# | fps                | 544           |
# | n_updates          | 55            |
# | policy_entropy     | 0.6096186     |
# | policy_loss        | 0.0027597784  |
# | serial_timesteps   | 7040          |
# | time_elapsed       | 20.6          |
# | total_timesteps    | 7040          |
# | value_loss         | 65.3905       |
# --------------------------------------
# --------------------------------------
# | approxkl           | 5.5065942e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00975       |
# | fps                | 560           |
# | n_updates          | 56            |
# | policy_entropy     | 0.55227995    |
# | policy_loss        | -0.0006251744 |
# | serial_timesteps   | 7168          |
# | time_elapsed       | 20.9          |
# | total_timesteps    | 7168          |
# | value_loss         | 39.17701      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.6206492e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0065       |
# | fps                | 524           |
# | n_updates          | 57            |
# | policy_entropy     | 0.58420616    |
# | policy_loss        | -0.0015896251 |
# | serial_timesteps   | 7296          |
# | time_elapsed       | 21.1          |
# | total_timesteps    | 7296          |
# | value_loss         | 57.370007     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.0299881e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0766        |
# | fps                | 545           |
# | n_updates          | 58            |
# | policy_entropy     | 0.6043607     |
# | policy_loss        | -0.0014623248 |
# | serial_timesteps   | 7424          |
# | time_elapsed       | 21.3          |
# | total_timesteps    | 7424          |
# | value_loss         | 67.99192      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.1174908e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.189         |
# | fps                | 600           |
# | n_updates          | 59            |
# | policy_entropy     | 0.5875757     |
# | policy_loss        | 0.00029443158 |
# | serial_timesteps   | 7552          |
# | time_elapsed       | 21.6          |
# | total_timesteps    | 7552          |
# | value_loss         | 74.39848      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 8.3924955e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.26          |
# | fps                | 572           |
# | n_updates          | 60            |
# | policy_entropy     | 0.56117666    |
# | policy_loss        | -0.0015345386 |
# | serial_timesteps   | 7680          |
# | time_elapsed       | 21.8          |
# | total_timesteps    | 7680          |
# | value_loss         | 56.826992     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00011814699 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.332         |
# | fps                | 544           |
# | n_updates          | 61            |
# | policy_entropy     | 0.5879508     |
# | policy_loss        | -0.0013736328 |
# | serial_timesteps   | 7808          |
# | time_elapsed       | 22            |
# | total_timesteps    | 7808          |
# | value_loss         | 60.08647      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 3.1745207e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0728        |
# | fps                | 546            |
# | n_updates          | 62             |
# | policy_entropy     | 0.58523625     |
# | policy_loss        | -0.00010715937 |
# | serial_timesteps   | 7936           |
# | time_elapsed       | 22.3           |
# | total_timesteps    | 7936           |
# | value_loss         | 76.72712       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0024886318  |
# | clipfrac           | 0.005859375   |
# | explained_variance | 0.11          |
# | fps                | 594           |
# | n_updates          | 63            |
# | policy_entropy     | 0.60276246    |
# | policy_loss        | -0.0015520956 |
# | serial_timesteps   | 8064          |
# | time_elapsed       | 22.5          |
# | total_timesteps    | 8064          |
# | value_loss         | 52.200325     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00016261988 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.11          |
# | fps                | 568           |
# | n_updates          | 64            |
# | policy_entropy     | 0.58358353    |
# | policy_loss        | -0.0007481993 |
# | serial_timesteps   | 8192          |
# | time_elapsed       | 22.7          |
# | total_timesteps    | 8192          |
# | value_loss         | 54.559483     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.2769556e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.186         |
# | fps                | 529           |
# | n_updates          | 65            |
# | policy_entropy     | 0.58769       |
# | policy_loss        | 0.00032149797 |
# | serial_timesteps   | 8320          |
# | time_elapsed       | 22.9          |
# | total_timesteps    | 8320          |
# | value_loss         | 73.38935      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0015901518 |
# | clipfrac           | 0.015625     |
# | explained_variance | 0.346        |
# | fps                | 525          |
# | n_updates          | 66           |
# | policy_entropy     | 0.6067877    |
# | policy_loss        | 0.0076453458 |
# | serial_timesteps   | 8448         |
# | time_elapsed       | 23.2         |
# | total_timesteps    | 8448         |
# | value_loss         | 53.1364      |
# -------------------------------------
# --------------------------------------
# | approxkl           | 1.9480587e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0339        |
# | fps                | 514           |
# | n_updates          | 67            |
# | policy_entropy     | 0.5857141     |
# | policy_loss        | 0.00045922253 |
# | serial_timesteps   | 8576          |
# | time_elapsed       | 23.4          |
# | total_timesteps    | 8576          |
# | value_loss         | 73.76768      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 6.843095e-05 |
# | clipfrac           | 0.0          |
# | explained_variance | -0.0157      |
# | fps                | 604          |
# | n_updates          | 68           |
# | policy_entropy     | 0.558784     |
# | policy_loss        | 0.0014489489 |
# | serial_timesteps   | 8704         |
# | time_elapsed       | 23.7         |
# | total_timesteps    | 8704         |
# | value_loss         | 45.100903    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 2.6560665e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.478         |
# | fps                | 580           |
# | n_updates          | 69            |
# | policy_entropy     | 0.5760665     |
# | policy_loss        | -0.0008321444 |
# | serial_timesteps   | 8832          |
# | time_elapsed       | 23.9          |
# | total_timesteps    | 8832          |
# | value_loss         | 50.425976     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 7.017473e-06  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.177         |
# | fps                | 608           |
# | n_updates          | 70            |
# | policy_entropy     | 0.59904       |
# | policy_loss        | -1.569622e-05 |
# | serial_timesteps   | 8960          |
# | time_elapsed       | 24.1          |
# | total_timesteps    | 8960          |
# | value_loss         | 71.493164     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00027681858 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.155         |
# | fps                | 620           |
# | n_updates          | 71            |
# | policy_entropy     | 0.56871563    |
# | policy_loss        | 0.005294576   |
# | serial_timesteps   | 9088          |
# | time_elapsed       | 24.3          |
# | total_timesteps    | 9088          |
# | value_loss         | 59.257755     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00022674294 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.443         |
# | fps                | 594           |
# | n_updates          | 72            |
# | policy_entropy     | 0.6049791     |
# | policy_loss        | -0.004042105  |
# | serial_timesteps   | 9216          |
# | time_elapsed       | 24.5          |
# | total_timesteps    | 9216          |
# | value_loss         | 48.432014     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.3847391e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.389         |
# | fps                | 608           |
# | n_updates          | 73            |
# | policy_entropy     | 0.5885994     |
# | policy_loss        | 5.953305e-05  |
# | serial_timesteps   | 9344          |
# | time_elapsed       | 24.7          |
# | total_timesteps    | 9344          |
# | value_loss         | 66.92055      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.001115138   |
# | clipfrac           | 0.01171875    |
# | explained_variance | 0.394         |
# | fps                | 546           |
# | n_updates          | 74            |
# | policy_entropy     | 0.54017824    |
# | policy_loss        | -0.0106645245 |
# | serial_timesteps   | 9472          |
# | time_elapsed       | 24.9          |
# | total_timesteps    | 9472          |
# | value_loss         | 59.655655     |
# --------------------------------------
# ------------------------------------
# | approxkl           | 0.000735751 |
# | clipfrac           | 0.005859375 |
# | explained_variance | 0.158       |
# | fps                | 618         |
# | n_updates          | 75          |
# | policy_entropy     | 0.5795957   |
# | policy_loss        | 0.010542701 |
# | serial_timesteps   | 9600        |
# | time_elapsed       | 25.2        |
# | total_timesteps    | 9600        |
# | value_loss         | 67.39949    |
# ------------------------------------
# --------------------------------------
# | approxkl           | 2.8696395e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.107         |
# | fps                | 542           |
# | n_updates          | 76            |
# | policy_entropy     | 0.5842083     |
# | policy_loss        | 0.0018708302  |
# | serial_timesteps   | 9728          |
# | time_elapsed       | 25.4          |
# | total_timesteps    | 9728          |
# | value_loss         | 65.01203      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 4.197253e-06  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00572       |
# | fps                | 616           |
# | n_updates          | 77            |
# | policy_entropy     | 0.56590706    |
# | policy_loss        | -0.0003578905 |
# | serial_timesteps   | 9856          |
# | time_elapsed       | 25.6          |
# | total_timesteps    | 9856          |
# | value_loss         | 52.316456     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.962752e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.12          |
# | fps                | 523           |
# | n_updates          | 78            |
# | policy_entropy     | 0.56689334    |
# | policy_loss        | -0.0014439534 |
# | serial_timesteps   | 9984          |
# | time_elapsed       | 25.8          |
# | total_timesteps    | 9984          |
# | value_loss         | 49.16021      |
# --------------------------------------
# /Users/sellintang/miniconda/envs/tf/lib/python3.6/site-packages/gym/logger.py:34: UserWarning: WARN: You are calling 'step()' even though this environment has already returned done = True. You should always call 'reset()' once you receive 'done = True' -- any further steps are undefined behavior.
#   warnings.warn(colorize("%s: %s" % ("WARN", msg % args), "yellow"))
